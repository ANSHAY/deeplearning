# %% [markdown]
# # import libraries

# %%
import tensorflow as tf
import tensorflow.keras.layers as Layers
import numpy as np
import matplotlib.pyplot as plt
import time

from IPython import display

# %% [markdown]
# # define parameters

# %%
LOSS = 'categorical_crossentropy'
OPTIMIZER_D = tf.keras.optimizers.RMSprop()
OPTIMIZER_A = tf.keras.optimizers.RMSprop()
METRICS = 'accuracy'
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)

INPUT_LENGTH = 128
BUFFER_SIZE = 60000
INITIALIZER = "random_normal"

EPOCHS = 20
BATCH_SIZE = 256

INPUT_SHAPE = (28, 28, 1)

# %% [markdown]
# # load data

# %%
(x_train, y_train), (_, _) = tf.keras.datasets.fashion_mnist.load_data()
x_train = np.expand_dims(x_train, axis=-1).astype('float32')
x_train = (x_train)/255.0

y_train = y_train + 1
INPUT_LENGTH = np.unique(y_train).shape[0] + 1

print(x_train.shape)
print(np.max(x_train))
# Out:
# (60000, 28, 28, 1)
# 1.0

# %%
# Batch and shuffle the data
x_train = tf.data.Dataset.from_tensor_slices(x_train)
x_train = x_train.batch(BATCH_SIZE, drop_remainder=True)

y_train = tf.data.Dataset.from_tensor_slices(y_train)
y_train = y_train.batch(BATCH_SIZE, drop_remainder=True)

# %% [markdown]
# # define model

# %% [markdown]
# ### generator

# %%
def generator():
    dim = INPUT_SHAPE[0]//2
    depth = 32
    model = tf.keras.models.Sequential()

    model.add(Layers.Dense(dim*dim*depth, input_dim=INPUT_LENGTH))
    model.add(Layers.BatchNormalization())
    model.add(Layers.LeakyReLU())

    model.add(Layers.Reshape((dim, dim, depth)))

    model.add(Layers.Conv2DTranspose(depth//2, 3, strides=2, padding='same', activation='selu', kernel_initializer=INITIALIZER))
    model.add(Layers.BatchNormalization())
    model.add(Layers.Conv2DTranspose(depth//2, 3, strides=1, padding='same', activation='selu', kernel_initializer=INITIALIZER))
    model.add(Layers.BatchNormalization())

    model.add(Layers.Conv2DTranspose(INPUT_SHAPE[2], 3, strides=1, activation='tanh', padding='same', kernel_initializer=INITIALIZER))

    model.summary()
    return model

# %% [markdown]
# ### discriminator

# %%
def discriminator():
    model = tf.keras.models.Sequential()

    model.add(Layers.Conv2D(64, 3, strides=2, padding='same', input_shape=INPUT_SHAPE))
    model.add(Layers.LeakyReLU())
    model.add(Layers.Dropout(0.3))

    model.add(Layers.Conv2D(128, 7, strides=2, padding='same'))
    model.add(Layers.LeakyReLU())

    model.add(Layers.Flatten())

    model.add(Layers.Dense(INPUT_LENGTH, activation='softmax'))
    model.summary()
    return model

# %% [markdown]
# # Full model

# %%
gen = generator()
discr = discriminator()

discr.compile(loss=LOSS, optimizer=OPTIMIZER_D)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 6272)              75264
# _________________________________________________________________
# batch_normalization (BatchNo (None, 6272)              25088
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 6272)              0
# _________________________________________________________________
# reshape (Reshape)            (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 28, 28, 16)        4624
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 28, 28, 16)        64
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 28, 28, 16)        2320
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 28, 28, 16)        64
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 28, 28, 1)         145
# =================================================================
# Total params: 107,569
# Trainable params: 94,961
# Non-trainable params: 12,608
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 14, 14, 64)        640
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 7, 7, 128)         401536
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 11)                69003
# =================================================================
# Total params: 471,179
# Trainable params: 471,179
# Non-trainable params: 0
# _________________________________________________________________

# %%
advr = tf.keras.models.Sequential([gen, discr])
advr.compile(loss=LOSS, optimizer=OPTIMIZER_A)

# %% [markdown]
# # Define train step

# %%
def train_step(images, labels):
    gen, discr = advr.layers
    labels = tf.keras.utils.to_categorical(labels, num_classes=INPUT_LENGTH)
    fake_images = gen(labels)
    x_d = tf.concat([images, fake_images], axis=0)
    y_d = tf.concat([labels, tf.zeros_like(labels)], axis=0)
    discr.trainable = True
    discr.train_on_batch(x_d, y_d)
    discr.trainable = False
    advr.train_on_batch(labels, labels)
    #return gen_loss, disc_loss

# %% [markdown]
# # Train model

# %%
seed = np.random.randint(0, INPUT_LENGTH, 16)
seed = tf.keras.utils.to_categorical(seed, num_classes=INPUT_LENGTH)

# %%
def generate_and_save_images(model, epoch, test_input):
  predictions = model(test_input, training=False)

  fig = plt.figure(figsize=(4,4))

  for i in range(predictions.shape[0]):
      plt.subplot(4, 4, i+1)
      plt.imshow(predictions[i, :, :, 0] * 127.5 + 127.5, cmap='gray')
      plt.axis('off')

  plt.savefig('image_at_epoch_{:04d}.png'.format(epoch))
  plt.show()

# %%
def print_weight_matrices(model):
    weights = []
    for l in model.layers:
      if l.trainable == True:
        weights.append(l.get_weights()[0])
    #print(len(weights))
    fig = plt.figure(figsize=(4, 4))
    for i in range(len(weights)):
        plt.subplot(4, 4, i+1)
        plt.imshow(weights[i], cmap='gray')
        plt.axis('off')
    plt.show()

# %%
def train(x_train, y_train, epochs):
    for e in range(epochs):
      start = time.time()
      for image_batch, label_batch in zip(x_train, y_train):
          train_step(image_batch, label_batch)
      # Produce images for the GIF as we go
      display.clear_output(wait=True)
      generate_and_save_images(gen, e + 1, seed)
      # print_weight_matrices(gen)
      # print_weight_matrices(discr)

      print ('Time for epoch {} is {} sec'.format(e + 1, time.time()-start))

    # Generate after the final epoch
    display.clear_output(wait=True)
    generate_and_save_images(gen, epochs, seed)

# %%
train(x_train, y_train, EPOCHS)

# %% [markdown]
# # Generate new images

# %%
num_images = 10
inp = np.random.randint(0, INPUT_LENGTH, num_images)
inp = tf.keras.utils.to_categorical(inp, num_classes=INPUT_LENGTH)
generated_images = gen(inp, training=False)*255.0

# %% [markdown]
# # View generated images

# %%
plt.imshow(np.squeeze(generated_images[np.random.randint(num_images)]), cmap='gray')
